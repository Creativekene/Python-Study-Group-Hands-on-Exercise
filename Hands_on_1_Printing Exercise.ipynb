# %%
print("Hello, World")
print("My name is Ekene")
print("I am Learning Python.")
print("Programming is exciting!")
# Out:
# Hello, World
# My name is Ekene
# I am Learning Python.
# Programming is exciting!

# %%
print("My favorite food is Plantain and Egg")
print("My favorite series is Game of Thrones")
print("My favorite sport is Basketball")
print("My favorite colour is Blue")
# Out:
# My favorite food is Plantain and Egg
# My favorite series is Game of Thrones
# My favorite sport is Basketball
# My favorite colour is Blue

# %%
print(15+5)
print(30-12)
print(9*8)
print(72/9)
print(18%5)
print(15+5)
print(10//3)
print(5**2)
# Out:
# 20
# 18
# 72
# 8.0
# 2
# 20
# 3
# 25

# %%
print("Python") # Display programming language
print("Programming") # Display computer concept
print("Lesson One") # Here's Lesson one
# Out:
# Python
# Programming
# Lesson One

# %%
print("My name is Ekene") # Praise be to God
print("My dream career is Tech and research in innovation medicine") # Let's see hoe it goed
print("Nigeria, my country") # The land filled with milk and honey
print(25+75) # Ofcouurse its 100
print(40//6)
print(8**2)
# Out:
# My name is Ekene
# My dream career is Tech and research in innovation medicine
# Nigeria, my country
# 100
# 6
# 64
