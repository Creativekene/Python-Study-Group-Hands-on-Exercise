# %% [markdown]
# # Exercise 1

# %%
employee_record = "EMP-HR-2026-004512"

prefix = employee_record[0:3]
department = employee_record[4:6]
year = employee_record[7:11]
emp_number = employee_record[12:]

first_10 = employee_record[:10] 
last_6 = employee_record[-6:]

every_second = employee_record[::2]
every_third = employee_record[::3]

reverse_record = employee_record[::-1]

print(f"Employee Prefix: {prefix}")
print(f"Department: {department}")
print(f"Employment Year: {year}")
print(f"Employee Number: {emp_number}")
print(f"First 10 Characters: {first_10}")
print(f"Last 6 Characters: {last_6}")
print(f"Every Second Character: {every_second}")
print(f"Every Third Character: {every_third}")
print(f"Reverse: {reverse_record}")
# Out:
# Employee Prefix: EMP
# Department: HR
# Employment Year: 2026
# Employee Number: 004512
# First 10 Characters: EMP-HR-202
# Last 6 Characters: 004512
# Every Second Character: EPH-06041
# Every Third Character: E--205
# Reverse: 215400-6202-RH-PME

# %% [markdown]
# # Exercise 2

# %%
card_number = "5489123476549876"

first_4 = card_number[:4]

last_4 = card_number[-4:]

middle_8 = card_number[4:12]

every_second = card_number[::2]

every_third = card_number[::3]

reverse_card = card_number[::-1]

last_8_reversed = card_number[-1:-9:-1] 

print("--- Security Extraction Results ---")
print(f"First 4 digits: {first_4}")
print(f"Last 4 digits: {last_4}")
print(f"Middle 8 digits: {middle_8}")
print(f"Every second digit: {every_second}")
print(f"Every third digit: {every_third}")
print(f"Entire card reversed: {reverse_card}")
print(f"Last 8 digits reversed: {last_8_reversed}")
# Out:
# --- Security Extraction Results ---
# First 4 digits: 5489
# Last 4 digits: 9876
# Middle 8 digits: 12347654
# Every second digit: 58137597
# Every third digit: 593696
# Entire card reversed: 6789456743219845
# Last 8 digits reversed: 67894567

# %% [markdown]
# # Exercise 3

# %%
customer_record = "CUS-LAG-2026-000451"

prefix = customer_record[0:3]
city_code = customer_record[4:7]
reg_year = customer_record[8:12]
cust_number = customer_record[13:]
first_8 = customer_record[:8]
last_5 = customer_record[-5:]
every_second = customer_record[::2]
every_third = customer_record[::3]
reverse_record = customer_record[::-1]

customer_name = "Christopher Johnson"

first_name = customer_name[:11] 
last_name = customer_name[12:]
first_5_letters = customer_name[:5]
last_7_letters = customer_name[-7:]
reversed_name = customer_name[::-1]

print(f"Customer Prefix: {prefix}")
print(f"City Code: {city_code}")
print(f"Registration Year: {reg_year}")
print(f"Customer Number: {cust_number}")
print(f"First 8 Characters: {first_8}")
print(f"Last 5 Characters: {last_5}")
print(f"Every Second Character: {every_second}")
print(f"Every Third Character: {every_third}")
print(f"Reverse Record: {reverse_record}")
print(f"First Name: {first_name}")
print(f"Last Name: {last_name}")
print(f"First 5 Letters: {first_5_letters}")
print(f"Last 7 Letters: {last_7_letters}")
print(f"Reversed Name: {reversed_name}")
# Out:
# Customer Prefix: CUS
# City Code: LAG
# Registration Year: 2026
# Customer Number: 000451
# First 8 Characters: CUS-LAG-
# Last 5 Characters: 00451
# Every Second Character: CSLG22-041
# Every Third Character: C-G0-01
# Reverse Record: 154000-6202-GAL-SUC
# First Name: Christopher
# Last Name: Johnson
# First 5 Letters: Chris
# Last 7 Letters: Johnson
# Reversed Name: nosnhoJ rehpotsirhC
