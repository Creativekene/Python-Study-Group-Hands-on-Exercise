# %% [markdown]
# # LESSON 5 HANDS-ON EXERCISE

# %% [markdown]
# ## Customer Registration

# %%
# Customer Registration System

# Create variables
customer_name = "John Doe"
email_address = "john.doe@email.com"
phone_number = "+234 801 234 5678"
country = "Nigeria"
occupation = "Software Developer"

# Print 
print("Customer Registration")
print()
print("Name:", customer_name)
print("Email:", email_address)
print("Phone:", phone_number)
print("Country:", country)
print("Occupation:", occupation)
# Out:
# Customer Registration
#
# Name: John Doe
# Email: john.doe@email.com
# Phone: +234 801 234 5678
# Country: Nigeria
# Occupation: Software Developer

# %% [markdown]
# ## Hospital Patient Record

# %%
# Create variables
patient_name = "Aisha Bello"
doctor = "Dr. Michael Okafor"
diagnosis = "Malaria with Mild Anemia"
blood_group = "O+"
hospital = "StartX General Hospital"

record = f"""PATIENT RECORD

Patient: {patient_name}
Doctor: {doctor}
Diagnosis: {diagnosis}
Blood Group: {blood_group}
Hospital: {hospital}"""

print(record)
# Out:
# PATIENT RECORD
#
# Patient: Aisha Bello
# Doctor: Dr. Michael Okafor
# Diagnosis: Malaria with Mild Anemia
# Blood Group: O+
# Hospital: StartX General Hospital

# %% [markdown]
# ## AI Prompt Builder

# %%
# Create a multiline string prompt
prompt = """You are an AI Assistant.

Analyze customer feedback.
Identify common complaints.
Provide recommendations.
Generate a summary report.

Bonus Instruction: Categorize feedback by sentiment: Positive, Negative, or Neutral, and give 3 action points for the product team."""

# Print 
print(prompt)
# Out:
# You are an AI Assistant.
#
# Analyze customer feedback.
# Identify common complaints.
# Provide recommendations.
# Generate a summary report.
#
# Bonus Instruction: Categorize feedback by sentiment: Positive, Negative, or Neutral, and give 3 action points for the product team.

# %% [markdown]
# # REAL WORD CASE STUDY

# %%
# Customer Feedback Report - Insight Retail Technologies

# 1. Store information as strings
customer_name = "Sarah Johnson"
product_name = "Wireless Mouse"
product_category = "Computer Accessories"
customer_rating = "5 Stars"
customer_review = "The product arrived on time, was easy to install, and exceeded my expectations. I would definitely recommend it to others."

# 2. Use a multiline string to generate a well-formatted report
report = f"""==================================================
           CUSTOMER FEEDBACK REPORT
==================================================

Customer Name: {customer_name}
Product      : {product_name}
Category     : {product_category}
Rating       : {customer_rating}

Customer Review
----------------
{customer_review}

==================================================
"""

# 3. Print the report to the screen
print(report)
print("Thank you for your feedback!")
# Out:
# ...
#            CUSTOMER FEEDBACK REPORT
# ...
#
# Customer Name: Sarah Johnson
# Product      : Wireless Mouse
# Category     : Computer Accessories
# Rating       : 5 Stars
#
# Customer Review
# ----------------
# The product arrived on time, was easy to install, and exceeded my expectations. I would definitely recommend it to others.
#
# ...
#
# Thank you for your feedback!
